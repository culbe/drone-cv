# %%
from ultralytics import YOLO
from visuals import *

# %%
model = YOLO('trainingResults/500epochRun/weights/best.pt')

# %%
draw_bounding_boxes_tensor('datasets/images/val/0000117_02708_d_0000090.jpg', model('datasets/images/val/0000117_02708_d_0000090.jpg')[0].boxes.data)
# Out:
# image 1/1 c:\Users\13095\OneDrive\CSE398\drone-cv\datasets\images\val\0000117_02708_d_0000090.jpg: 384x640 17 pedetrians, 3 peoples, 16 cars, 1 van, 1 motor, 176.7ms
# Speed: 11.0ms preprocess, 176.7ms inference, 2757.6ms postprocess per image at shape (1, 3, 384, 640)
